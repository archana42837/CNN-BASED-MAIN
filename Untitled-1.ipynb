# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Parameters
IMG_HEIGHT, IMG_WIDTH, CHANNELS = 512, 512, 3
BATCH_SIZE = 32
EPOCHS = 500
SPECS= 'with specs 1'  # Update this to your images folder
SPECS1= 'without specs'
# Function to load images from a directory
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
        img_array = img_to_array(img) / 255.0  # Normalize to [0, 1]
        images.append(img_array)
    return np.array(images)

# %%
# Load and preprocess dataset
y_images = load_images_from_folder(SPECS)
x_images = load_images_from_folder(SPECS1)
# Split the dataset into training and validation sets
#train_images, val_images = train_test_split(x_images, test_size=0.2, random_state=42)

# Define the U-Net model
def create_unet_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS)):
    inputs = layers.Input(shape=input_shape)
   
    # Encoder
    x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(inputs)
    #x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    # Additional downsampling layers can be added
    x = layers.Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    # Bottleneck
    x = layers.Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
    
    # Decoder
    x = layers.Conv2DTranspose(128, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.UpSampling2D(size=(2, 2))(x)
    
    x = layers.Conv2DTranspose(64, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.UpSampling2D(size=(2, 2))(x)

    outputs = layers.Conv2D(3, kernel_size=3, padding='same', activation='sigmoid')(x)
    
    model = keras.Model(inputs, outputs)
    return model

# %%
 #Create and compile the model
model = create_unet_model()
model.summary()
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 128, 128, 128)  │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 256, 256, 64)   │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 512, 512, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 512, 512, 3)    │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741,379 (2.83 MB)
#  Trainable params: 741,379 (2.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(x_images, y_images, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE)
#,validation_data=(val_images, val_images)
# Save the model
model.save('SPECS.h5')
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0755
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0727
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0788
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0719
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0730
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0729
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0721
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0702
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0682
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0652
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0620
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0616
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0706
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0728
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0736
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0678
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0642
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0629
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0634
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0656
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0652
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0642
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0640
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0640
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0639
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0635
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0628
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0620
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0614
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0608
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0598
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0594
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0592
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0586
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0585
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0577
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0573
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0569
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0569
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0565
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0564
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0561
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0557
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0553
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0549
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0545
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0546
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0553
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0546
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0534
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0531
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0536
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0543
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0526
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0515
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0517
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0523
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0553
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0538
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0499
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0518
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - loss: 0.0504
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: 0.0499
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0507
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0487
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0491
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0504
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0486
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0472
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0463
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0461
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0497
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0785
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0571
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: 0.0594
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: 0.0520
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0549
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0554
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0539
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0542
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0548
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0548
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0536
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0520
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0527
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0536
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0526
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0515
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0511
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0513
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0510
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0501
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0493
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0493
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0484
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0476
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 0.0475
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0469
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0470
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0470
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0465
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0459
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0448
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0452
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0461
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0517
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0444
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0469
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0482
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0453
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0482
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0447
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0469
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0462
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0445
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0450
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0443
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0441
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0430
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0444
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 0.0425
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0427
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0426
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0415
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0421
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0414
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0411
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0420
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0405
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0403
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0399
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 0.0397
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0403
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0400
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0410
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0386
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0387
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0395
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0389
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 0.0376
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0375
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0380
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0374
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0372
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0370
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0360
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0360
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0359
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0357
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 0.0355
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0384
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0451
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0437
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0367
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0411
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0368
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0393
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0377
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0375
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0366
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0368
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0363
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0358
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0345
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0358
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0347
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0340
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0340
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0342
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0332
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0332
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0331
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0327
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0323
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0323
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0322
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0326
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0336
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0351
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0355
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0323
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0323
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0327
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0319
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0332
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0318
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0320
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0335
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0311
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0324
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0320
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0308
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0317
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0300
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0311
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0297
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0300
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: 0.0298
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.0294
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0295
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0297
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.0293
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.0300
# Epoch 204/500

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# Load the trained model
model = keras.models.load_model('Specs.h5')

# Function to preprocess the image
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(512, 512))  # Resize to model input size
    img_array = img_to_array(img) / 255.0  # Normalize to [0, 1]
    return np.expand_dims(img_array, axis=0)  # Add batch dimension

# Function to plot input and output images
def plot_input_output(input_image, output_image):
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title('Input Image')
    plt.imshow(input_image)
    plt.axis('off')
 
    plt.subplot(1, 2, 2)
    plt.title('Output Image')
    plt.imshow(output_image)
    plt.axis('off')

    plt.show()

# Path to the input image
image_path = 'Picture 3.jpg'  # Update this to your input image path

# Preprocess the input image
input_image = preprocess_image(image_path)

# Predict the output
output_image = model.predict(input_image)

# Squeeze the output to remove the batch dimension
output_image = np.squeeze(output_image)

# Plot the input and output images
plot_input_output(input_image[0], output_image)
